# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehadevop/devopss/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# Load dataset
iris_data = load_iris()

# Convert to DataFrame for better understanding
df = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
df["Target"] = iris_data.target

# Separate features and labels
X = df.drop("Target", axis=1)
y = df["Target"]

print("Total Samples and Features:", X.shape)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1
)

# Create Decision Tree model
dt_model = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=1)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions
predictions = dt_model.predict(X_test)

# Evaluate performance
print("\nModel Accuracy:", accuracy_score(y_test, predictions))
print("\nDetailed Classification Report:\n")
print(classification_report(y_test, predictions, target_names=iris_data.target_names))

# Visualize the decision tree
plt.figure(figsize=(10, 7))
plot_tree(
    dt_model,
    feature_names=iris_data.feature_names,
    class_names=iris_data.target_names,
    filled=True,
    rounded=True
)
plt.title("Iris Decision Tree Classifier")
plt.show()

# Final Observations
print("\nObservations:")
print("1. The model predicts Iris species effectively.")
print("2. Petal-related features dominate decision making.")
print("3. Controlled depth avoids overfitting.")
# Out:
# Total Samples and Features: (150, 4)
#
# Model Accuracy: 0.9666666666666667
#
# Detailed Classification Report:
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.86      1.00      0.92         6
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30
# Observations:
# 1. The model predicts Iris species effectively.
# 2. Petal-related features dominate decision making.
# 3. Controlled depth avoids overfitting.
